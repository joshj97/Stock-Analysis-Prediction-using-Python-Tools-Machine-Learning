# %%
import os
import sys
#from stocker import Stocker
# %config IPCompleter.greedy=True
import io
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import pandas_datareader as pdr
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
import datetime
from matplotlib import style
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsClassifier
#Importing metrics for the accuracy
from sklearn.metrics import accuracy_score

# %%
pwd
# Out:
# '/Users/josh/Desktop/HealthcareData'

# %%
cd desktop/HealthcareData
# Out:
# [Errno 2] No such file or directory: 'desktop/HealthcareData'
# /Users/josh/Desktop/HealthcareData

# %%
REGN_df = pd.read_csv('Regn2.csv')
REGN_df.head(22)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0    11/4/19  313.049988  315.940002  310.739990  311.040009  311.040009
# 1    11/5/19  323.359985  344.100006  322.109985  332.600006  332.600006
# 2    11/6/19  331.369995  333.279999  324.269989  324.489990  324.489990
# 3    11/7/19  329.179993  333.720001  325.619995  326.390015  326.390015
# 4    11/8/19  327.519989  342.470001  327.029999  341.790009  341.790009
# 5   11/11/19  340.339996  344.989990  338.709991  344.279999  344.279999
# 6   11/12/19  344.000000  349.940002  341.359985  348.410004  348.410004
# 7   11/13/19  346.329987  349.630005  341.820007  348.299988  348.299988
# 8   11/14/19  349.799988  350.000000  337.029999  338.390015  338.390015
# 9   11/15/19  340.950012  349.859985  338.709991  344.869995  344.869995
# 10  11/18/19  342.589996  344.209991  337.529999  340.190002  340.190002
# 11  11/19/19  344.179993  348.190002  340.209991  344.459991  344.459991
# 12  11/20/19  341.980011  347.420013  341.980011  344.239990  344.239990
# 13  11/21/19  343.600006  353.000000  341.609985  350.779999  350.779999
# 14  11/22/19  350.929993  365.739990  350.929993  360.660004  360.660004
# 15  11/25/19  362.440002  367.019989  358.480011  366.820007  366.820007
# 16  11/26/19  366.869995  367.399994  361.760010  363.829987  363.829987
# 17  11/27/19  365.070007  372.589996  364.619995  371.579987  371.579987
# 18  11/29/19  372.059998  372.470001  366.769989  369.000000  369.000000
# 19   12/2/19  368.179993  369.000000  363.070007  366.079987  366.079987
# 20   12/3/19  366.989990  369.500000  363.399994  368.809998  368.809998
# 21   12/4/19  369.190002  373.339996  367.570007  369.970001  369.970001
#
#      Volume
# 0    632800
# 1   2345400
# 2   1017500
# 3    952300
# 4   1106100
# 5    611900
# 6    905400
# 7   1009400
# 8   1029600
# 9    912200
# 10   622500
# 11   630800
# 12  1058100
# 13   858300
# 14  1286400
# 15   845000
# 16   735100
# 17   734400
# 18   463600
# 19   652200
# 20   929700
# 21   605000

# %% [markdown]
# #Prediction

# %%
#Using LSTM

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
np.random.seed(7)
# load the dataset
dataframe = read_csv('Regn2.csv', usecols=[5], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
look_back = 3
trainX, trainY = create_dataset(dataset, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0],1, trainX.shape[1]))
# create and fit the LSTM network
#trainX

# %%
model = Sequential()
model.add(LSTM(6, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.0841
# Epoch 2/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 10/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 19/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0033A: 0s - loss: 0.0
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 22/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 25/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 26/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 32/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 34/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 35/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 36/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 37/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 38/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 40/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 41/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 44/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 47/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 49/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 50/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 53/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 58/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 59/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 62/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 63/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 65/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 66/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 74/100
# 81/81 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 75/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 76/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 77/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 78/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 79/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 0.0024

# %%
# make predictions
trainPredict = model.predict(trainX[-1].reshape(1,1,3))
#testPredict = model.predict(testX)
trainPredict = scaler.inverse_transform(trainPredict)
print(trainPredict)
# Out:
# [[493.39304]]

# %%
for pred in prediction:
    print(pred)
# Out:
# 402.9013806002199
# 403.7832097093247
# 402.1913457622598
# 405.09902763833315
# 402.6418086260691
# 409.9196377389929
# 447.9661650931115
# 457.34324540779073
# 469.8869734769711
# 442.8267638140244
# 459.5960405205363
# 477.31845405652336
# 470.84740980824967
# 509.2437268399953
# 498.9254395044908

# %%
#Using Linear Regression for Regeneron Inc. 

forecast_time = int(15) # The number of predicitons that you want to make 
LR_df=REGN_df[['Open','High','Low','Close','Adj Close','Volume']].copy()  


#Replace Close with the column that you want to predict
LR_df['prediction'] = LR_df['Close'].shift(-1)
LR_df.dropna(inplace=True)
X1 = np.array(LR_df.drop(['prediction'], 1))
Y1 = np.array(LR_df['prediction'])
X2 = preprocessing.scale(X1)
X_prediction = X2[-forecast_time:]
X_train, X_test, Y_train, Y_test = train_test_split(X2, Y1, test_size=1)
clf = LinearRegression()
clf.fit(X_train, Y_train)
prediction = (clf.predict(X_prediction))

# %%
plt.title("Prediction")
plt.xlabel("Number of days")

#Replace * with the column that you want to predict
plt.ylabel("Closing Price");
plt.plot(prediction)
plt.show()

# %%
#we need to create the dataset of x and y which is the two data set we going to take to predict the model
#so we have to take the date and we taking the "Close" cloumn
dates = []
prices = []
REGN_df.tail(1)
# Out:
#       Date        Open       High    Low       Close   Adj Close   Volume
# 84  3/6/20  477.290009  496.98999  477.0  494.429993  494.429993  1130700
